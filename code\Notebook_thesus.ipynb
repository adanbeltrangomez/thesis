# %% [markdown]
# <a href="https://colab.research.google.com/github/adanbeltrangomez/thesis/blob/main/code%5CNotebook_thesus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# !python -m spacy download en_core_web_lg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.1.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.9.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.7)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.1.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# 2022-09-10 22:33:20.300128: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0-py3-none-any.whl (587.7 MB)
#      |████████████████████████████████| 587.7 MB 10 kB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.4.0) (3.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.6.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (8.1.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.4.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.9.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (21.3)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (4.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (4.64.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.21.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (1.24.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-lg==3.4.0) (2.0.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install reportlab
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting reportlab
#   Downloading reportlab-3.6.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 10.0 MB/s
# Collecting pillow>=9.0.0
#   Downloading Pillow-9.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 67.1 MB/s
# Installing collected packages: pillow, reportlab
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed pillow-9.2.0 reportlab-3.6.11

# %%
# !git clone https://github.com/Thesis2022-org/thesis2022-repo.git
# Out:
# Cloning into 'thesis2022-repo'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 32 (delta 4), reused 5 (delta 2), pack-reused 0
# Unpacking objects: 100% (32/32), done.

# %%
# %cd /content/thesis2022-repo/code/
# Out:
# /content/thesis2022-repo/code

# %%
# %ls
# Out:
# Gold.py  Notebook_thesus.ipynb  readme.txt  tags_map.py       Utils_Pln.py
# Main.py  __pycache__/           Reports.py  thesis2022-repo/

# %%
#comentario
#comentario2
#from google.colab import drive
#drive.mount('/content/drive')
#%cd /content/drive/MyDrive/UAB-IIIA/Thesis/Devolpment/code/



import csv
import Utils_Pln
import Main
import pandas as pd

class Gold:

    def __init__(self):
        '''

        '''

        # self.oUtilsPln = Utils_Pln.UtilPln()

        # self._NameFileNorms = self.oUtilsPln.Read_Config('FilePath_Norms')[0]

        self.norms = {}

    def evaluate(self, community, section, id):
        self.norms = self.readGold(id)

        for n in self.norms:
            n.process()



    def printResults(self):
        Main.Norm.writeCSV(self, self.norms)
        return

    def printGold(self, corpus, section):

        titles = ["Corpus", "Id", "Text", "g_s", "g_v", "g_o", "g_structure", "g_m", "g_p1", "g_p2", "g_a", "g_c",
                  "comments", "url"]
        lines = []
        lines.append(titles)

        for n in self.norms:
            # if n[8]  not in corpus or n[9] not in section:
            #    continue

            # name    = n[8]
            id = n.ID
            text = n.TEXT
            g_s = n.G_SUBJECT
            g_PClause = n.G_P_CLAUSE
            g_QClause = n.G_Q_CLAUSE
            g_v = n.G_VERBS
            g_o = n.G_OBJECT
            g_m = n.G_MODALITY
            g_p1 = n.G_PERSON1
            g_p2 = n.G_PERSON2
            g_c = n.G_P_CLAUSE
            g_a = n.G_ACTION

            lines.append([id, text, g_PClause, g_QClause, g_v, g_o, g_m, g_p1, g_p2, g_a, g_c])

        with open('Gold.csv', 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile, delimiter=';', quoting=csv.QUOTE_MINIMAL)

            for line in lines:
                writer.writerow(line)

    def readGold(self, id_norm):

        df = pd.read_excel("../Corpus/GoldStandard.xlsx", sheet_name='Gold')
        df = df.fillna("")

        self.norms = []  # {}

        for index, row in df.iterrows():
            oNorm = Main.Norm()

            oNorm.ID = row["Id"]
            if id_norm != "" and oNorm.ID != id_norm:
                continue

            oNorm.TEXT = row["Text"]
            oNorm.G_P_CLAUSE = row["P_Clause"].split("::")
            oNorm.G_Q_CLAUSE = row["Q_Clause"].split("::")
            oNorm.G_SUBJECT = row["Subject"].split("::")
            oNorm.G_OBJECT = row["Object"].split("::")
            oNorm.G_VERBS = row["Verb"].split("::")
            oNorm.G_MODALITY = row["Modality"].split("::")
            oNorm.G_PERSON1 = row["Person1"].split("::")
            oNorm.G_PERSON2 = row["Person2"].split("::")
            oNorm.G_P_VERB = row["P_Verb"].split("::")
            oNorm.G_P_VERB_TENSE = row["P_Verb_Tense"].split("::")
            oNorm.G_Q_VERB = row["Q_Verb"].split("::")
            oNorm.G_Q_VERB_TENSE = row["Q_Verb_Tense"].split("::")
            oNorm.G_STRUCTURE = row["Structure"]
            oNorm.G_ACTION = row["Action"].split("::")
            oNorm.G_VOICE = row["Voice"].split("::")
            oNorm.G_P_VERB_Tense_Q_VERB_TENSE = row["P_Verb_Tense+Q_Verb_Tense"]
            oNorm.G_CANONICAL = row["Canonical"]

            print("Procesando:\n", oNorm.ID)

            self.norms.append(oNorm)
        return self.norms


oGold = Gold()

# oGold.evaluate("GOLD-STANDARD-FACEBOOK","NORM","")
# oGold.print("GOLD-STANDARD-FACEBOOK","NORM")

oGold.evaluate("GOLD-STANDARD-BYU-BNC", "NORM", "")
oGold.printResults()
# Out:
# Procesando:
#  GOLD-CONDITIONALS-024
# Procesando:
#  GOLD-CONDITIONALS-086
# Procesando:
#  GOLD-CONDITIONALS-061
# Procesando:
#  GOLD-CONDITIONALS-006
# Procesando:
#  GOLD-CONDITIONALS-084
# Procesando:
#  GOLD-CONDITIONALS-051
# Procesando:
#  GOLD-CONDITIONALS-015
# Procesando:
#  GOLD-CONDITIONALS-054
# Procesando:
#  GOLD-CONDITIONALS-106
# Procesando:
#  GOLD-CONDITIONALS-002
# Procesando:
#  GOLD-CONDITIONALS-003
# Procesando:
#  GOLD-CONDITIONALS-004
# Procesando:
#  GOLD-CONDITIONALS-005
# Procesando:
#  GOLD-CONDITIONALS-007
# Procesando:
#  GOLD-CONDITIONALS-009
# Procesando:
#  GOLD-CONDITIONALS-010
# Procesando:
#  GOLD-CONDITIONALS-011
# Procesando:
#  GOLD-CONDITIONALS-012
# Procesando:
#  GOLD-CONDITIONALS-014
# Procesando:
#  GOLD-CONDITIONALS-016
# Procesando:
#  GOLD-CONDITIONALS-017
# Procesando:
#  GOLD-CONDITIONALS-018
# Procesando:
#  GOLD-CONDITIONALS-019
# Procesando:
#  GOLD-CONDITIONALS-020
# Procesando:
#  GOLD-CONDITIONALS-021
# Procesando:
#  GOLD-CONDITIONALS-022
# Procesando:
#  GOLD-CONDITIONALS-023
# Procesando:
#  GOLD-CONDITIONALS-026
# Procesando:
#  GOLD-CONDITIONALS-030
# Procesando:
#  GOLD-CONDITIONALS-031
# Procesando:
#  GOLD-CONDITIONALS-032
# Procesando:
#  GOLD-CONDITIONALS-033
# Procesando:
#  GOLD-CONDITIONALS-034
# Procesando:
#  GOLD-CONDITIONALS-035
# Procesando:
#  GOLD-CONDITIONALS-036
# Procesando:
#  GOLD-CONDITIONALS-037
# Procesando:
#  GOLD-CONDITIONALS-038
# Procesando:
#  GOLD-CONDITIONALS-039
# Procesando:
#  GOLD-CONDITIONALS-040
# Procesando:
#  GOLD-CONDITIONALS-041
# Procesando:
#  GOLD-CONDITIONALS-046
# Procesando:
#  GOLD-CONDITIONALS-047
# Procesando:
#  GOLD-CONDITIONALS-048
# Procesando:
#  GOLD-CONDITIONALS-049
# Procesando:
#  GOLD-CONDITIONALS-050
# Procesando:
#  GOLD-CONDITIONALS-052
# Procesando:
#  GOLD-CONDITIONALS-053
# Procesando:
#  GOLD-CONDITIONALS-055
# Procesando:
#  GOLD-CONDITIONALS-056
# Procesando:
#  GOLD-CONDITIONALS-057
# Procesando:
#  GOLD-CONDITIONALS-058
# Procesando:
#  GOLD-CONDITIONALS-059
# Procesando:
#  GOLD-CONDITIONALS-060
# Procesando:
#  GOLD-CONDITIONALS-062
# Procesando:
#  GOLD-CONDITIONALS-063
# Procesando:
#  GOLD-CONDITIONALS-064
# Procesando:
#  GOLD-CONDITIONALS-065
# Procesando:
#  GOLD-CONDITIONALS-066
# Procesando:
#  GOLD-CONDITIONALS-067
# Procesando:
#  GOLD-CONDITIONALS-068
# Procesando:
#  GOLD-CONDITIONALS-073
# Procesando:
#  GOLD-CONDITIONALS-074
# Procesando:
#  GOLD-CONDITIONALS-075
# Procesando:
#  GOLD-CONDITIONALS-076
# Procesando:
#  GOLD-CONDITIONALS-077
# Procesando:
#  GOLD-CONDITIONALS-078
# Procesando:
#  GOLD-CONDITIONALS-079
# Procesando:
#  GOLD-CONDITIONALS-080
# Procesando:
#  GOLD-CONDITIONALS-081
# Procesando:
#  GOLD-CONDITIONALS-082
# Procesando:
#  GOLD-CONDITIONALS-083
# Procesando:
#  GOLD-CONDITIONALS-085
# Procesando:
#  GOLD-CONDITIONALS-087
# Procesando:
#  GOLD-CONDITIONALS-088
# Procesando:
#  GOLD-CONDITIONALS-089
# Procesando:
#  GOLD-CONDITIONALS-090
# Procesando:
#  GOLD-CONDITIONALS-091
# Procesando:
#  GOLD-CONDITIONALS-092
# Procesando:
#  GOLD-CONDITIONALS-093
# Procesando:
#  GOLD-CONDITIONALS-094
# Procesando:
#  GOLD-CONDITIONALS-095
# Procesando:
#  GOLD-CONDITIONALS-096
# Procesando:
#  GOLD-CONDITIONALS-097
# Procesando:
#  GOLD-CONDITIONALS-099
# Procesando:
#  GOLD-CONDITIONALS-100
# Procesando:
#  GOLD-CONDITIONALS-102
# Procesando:
#  GOLD-CONDITIONALS-103
# Procesando:
#  GOLD-CONDITIONALS-104
# Procesando:
#  GOLD-CONDITIONALS-105
# Procesando:
#  GOLD-CONDITIONALS-107
# Procesando:
#  GOLD-CONDITIONALS-108
# Procesando:
#  GOLD-CONDITIONALS-109
# Procesando:
#  GOLD-CONDITIONALS-110
# Procesando:
#  GOLD-CONDITIONALS-111
# Procesando:
#  GOLD-CONDITIONALS-112
# Procesando:
#  GOLD-CONDITIONALS-113
# Procesando:
#  GOLD-CONDITIONALS-114
# Procesando:
#  GOLD-CONDITIONALS-115
# Procesando:
#  GOLD-CONDITIONALS-116
# Procesando:
#  GOLD-CONDITIONALS-117
# Procesando:
#  GOLD-CONDITIONALS-118
# Procesando:
#  GOLD-CONDITIONALS-119
# Procesando:
#  GOLD-CONDITIONALS-120
# Procesando:
#  GOLD-CONDITIONALS-121
# Procesando:
#  GOLD-CONDITIONALS-122
# Procesando:
#  GOLD-CONDITIONALS-123
# Procesando:
#  GOLD-CONDITIONALS-124
# Procesando:
#  GOLD-CONDITIONALS-125
# Procesando:
#  GOLD-CONDITIONALS-126
# Procesando:
#  GOLD-CONDITIONALS-127
# Procesando:
#  GOLD-CONDITIONALS-128
# Procesando:
#  GOLD-CONDITIONALS-129
# Procesando:
#  GOLD-CONDITIONALS-130
# Procesando:
#  GOLD-CONDITIONALS-131
# Procesando:
#  GOLD-CONDITIONALS-132
# Procesando:
#  GOLD-CONDITIONALS-133
# Procesando:
#  GOLD-CONDITIONALS-134
# Procesando:
#  GOLD-CONDITIONALS-135
# Procesando:
#  GOLD-CONDITIONALS-136
# Procesando:
#  GOLD-CONDITIONALS-137
# Procesando:
#  GOLD-CONDITIONALS-139
# Procesando:
#  GOLD-CONDITIONALS-140
# Procesando:
#  GOLD-CONDITIONALS-141
# Procesando:
#  GOLD-CONDITIONALS-142
# Procesando:
#  GOLD-CONDITIONALS-147
#
#  imprimiendo: GOLD-CONDITIONALS-024
#
#  imprimiendo: GOLD-CONDITIONALS-086
#
#  imprimiendo: GOLD-CONDITIONALS-061
#
#  imprimiendo: GOLD-CONDITIONALS-006
#
#  imprimiendo: GOLD-CONDITIONALS-084
#
#  imprimiendo: GOLD-CONDITIONALS-051
#
#  imprimiendo: GOLD-CONDITIONALS-015
#
#  imprimiendo: GOLD-CONDITIONALS-054
#
#  imprimiendo: GOLD-CONDITIONALS-106
#
#  imprimiendo: GOLD-CONDITIONALS-002
#
#  imprimiendo: GOLD-CONDITIONALS-003
#
#  imprimiendo: GOLD-CONDITIONALS-004
#
#  imprimiendo: GOLD-CONDITIONALS-005
#
#  imprimiendo: GOLD-CONDITIONALS-007
#
#  imprimiendo: GOLD-CONDITIONALS-009
#
#  imprimiendo: GOLD-CONDITIONALS-010
#
#  imprimiendo: GOLD-CONDITIONALS-011
#
#  imprimiendo: GOLD-CONDITIONALS-012
#
#  imprimiendo: GOLD-CONDITIONALS-014
#
#  imprimiendo: GOLD-CONDITIONALS-016
#
#  imprimiendo: GOLD-CONDITIONALS-017
#
#  imprimiendo: GOLD-CONDITIONALS-018
#
#  imprimiendo: GOLD-CONDITIONALS-019
#
#  imprimiendo: GOLD-CONDITIONALS-020
#
#  imprimiendo: GOLD-CONDITIONALS-021
#
#  imprimiendo: GOLD-CONDITIONALS-022
#
#  imprimiendo: GOLD-CONDITIONALS-023
#
#  imprimiendo: GOLD-CONDITIONALS-026
#
#  imprimiendo: GOLD-CONDITIONALS-030
#
#  imprimiendo: GOLD-CONDITIONALS-031
#
#  imprimiendo: GOLD-CONDITIONALS-032
#
#  imprimiendo: GOLD-CONDITIONALS-033
#
#  imprimiendo: GOLD-CONDITIONALS-034
#
#  imprimiendo: GOLD-CONDITIONALS-035
#
#  imprimiendo: GOLD-CONDITIONALS-036
#
#  imprimiendo: GOLD-CONDITIONALS-037
#
#  imprimiendo: GOLD-CONDITIONALS-038
#
#  imprimiendo: GOLD-CONDITIONALS-039
#
#  imprimiendo: GOLD-CONDITIONALS-040
#
#  imprimiendo: GOLD-CONDITIONALS-041
#
#  imprimiendo: GOLD-CONDITIONALS-046
#
#  imprimiendo: GOLD-CONDITIONALS-047
#
#  imprimiendo: GOLD-CONDITIONALS-048
#
#  imprimiendo: GOLD-CONDITIONALS-049
#
#  imprimiendo: GOLD-CONDITIONALS-050
#
#  imprimiendo: GOLD-CONDITIONALS-052
#
#  imprimiendo: GOLD-CONDITIONALS-053
#
#  imprimiendo: GOLD-CONDITIONALS-055
#
#  imprimiendo: GOLD-CONDITIONALS-056
#
#  imprimiendo: GOLD-CONDITIONALS-057
#
#  imprimiendo: GOLD-CONDITIONALS-058
#
#  imprimiendo: GOLD-CONDITIONALS-059
#
#  imprimiendo: GOLD-CONDITIONALS-060
#
#  imprimiendo: GOLD-CONDITIONALS-062
#
#  imprimiendo: GOLD-CONDITIONALS-063
#
#  imprimiendo: GOLD-CONDITIONALS-064
#
#  imprimiendo: GOLD-CONDITIONALS-065
#
#  imprimiendo: GOLD-CONDITIONALS-066
#
#  imprimiendo: GOLD-CONDITIONALS-067
#
#  imprimiendo: GOLD-CONDITIONALS-068
#
#  imprimiendo: GOLD-CONDITIONALS-073
#
#  imprimiendo: GOLD-CONDITIONALS-074
#
#  imprimiendo: GOLD-CONDITIONALS-075
#
#  imprimiendo: GOLD-CONDITIONALS-076
#
#  imprimiendo: GOLD-CONDITIONALS-077
#
#  imprimiendo: GOLD-CONDITIONALS-078
#
#  imprimiendo: GOLD-CONDITIONALS-079
#
#  imprimiendo: GOLD-CONDITIONALS-080
#
#  imprimiendo: GOLD-CONDITIONALS-081
#
#  imprimiendo: GOLD-CONDITIONALS-082
#
#  imprimiendo: GOLD-CONDITIONALS-083
#
#  imprimiendo: GOLD-CONDITIONALS-085
#
#  imprimiendo: GOLD-CONDITIONALS-087
#
#  imprimiendo: GOLD-CONDITIONALS-088
#
#  imprimiendo: GOLD-CONDITIONALS-089
#
#  imprimiendo: GOLD-CONDITIONALS-090
#
#  imprimiendo: GOLD-CONDITIONALS-091
#
#  imprimiendo: GOLD-CONDITIONALS-092
#
#  imprimiendo: GOLD-CONDITIONALS-093
#
#  imprimiendo: GOLD-CONDITIONALS-094
#
#  imprimiendo: GOLD-CONDITIONALS-095
#
#  imprimiendo: GOLD-CONDITIONALS-096
#
#  imprimiendo: GOLD-CONDITIONALS-097
#
#  imprimiendo: GOLD-CONDITIONALS-099
#
#  imprimiendo: GOLD-CONDITIONALS-100
#
#  imprimiendo: GOLD-CONDITIONALS-102
#
#  imprimiendo: GOLD-CONDITIONALS-103
#
#  imprimiendo: GOLD-CONDITIONALS-104
#
#  imprimiendo: GOLD-CONDITIONALS-105
#
#  imprimiendo: GOLD-CONDITIONALS-107
#
#  imprimiendo: GOLD-CONDITIONALS-108
#
#  imprimiendo: GOLD-CONDITIONALS-109
#
#  imprimiendo: GOLD-CONDITIONALS-110
#
#  imprimiendo: GOLD-CONDITIONALS-111
#
#  imprimiendo: GOLD-CONDITIONALS-112
#
#  imprimiendo: GOLD-CONDITIONALS-113
#
#  imprimiendo: GOLD-CONDITIONALS-114
#
#  imprimiendo: GOLD-CONDITIONALS-115
#
#  imprimiendo: GOLD-CONDITIONALS-116
#
#  imprimiendo: GOLD-CONDITIONALS-117
#
#  imprimiendo: GOLD-CONDITIONALS-118
#
#  imprimiendo: GOLD-CONDITIONALS-119
#
#  imprimiendo: GOLD-CONDITIONALS-120
#
#  imprimiendo: GOLD-CONDITIONALS-121
#
#  imprimiendo: GOLD-CONDITIONALS-122
#
#  imprimiendo: GOLD-CONDITIONALS-123
#
#  imprimiendo: GOLD-CONDITIONALS-124
#
#  imprimiendo: GOLD-CONDITIONALS-125
#
#  imprimiendo: GOLD-CONDITIONALS-126
#
#  imprimiendo: GOLD-CONDITIONALS-127
#
#  imprimiendo: GOLD-CONDITIONALS-128
#
#  imprimiendo: GOLD-CONDITIONALS-129
#
#  imprimiendo: GOLD-CONDITIONALS-130
#
#  imprimiendo: GOLD-CONDITIONALS-131
#
#  imprimiendo: GOLD-CONDITIONALS-132
#
#  imprimiendo: GOLD-CONDITIONALS-133
#
#  imprimiendo: GOLD-CONDITIONALS-134
#
#  imprimiendo: GOLD-CONDITIONALS-135
#
#  imprimiendo: GOLD-CONDITIONALS-136
#
#  imprimiendo: GOLD-CONDITIONALS-137
#
#  imprimiendo: GOLD-CONDITIONALS-139
#
#  imprimiendo: GOLD-CONDITIONALS-140
#
#  imprimiendo: GOLD-CONDITIONALS-141
#
#  imprimiendo: GOLD-CONDITIONALS-142
#
#  imprimiendo: GOLD-CONDITIONALS-147
#
# Subject= 3
# Verb= 3
# Object 3
# PClause 85

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
